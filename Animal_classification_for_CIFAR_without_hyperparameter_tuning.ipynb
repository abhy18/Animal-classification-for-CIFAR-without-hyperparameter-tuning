# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
dt = keras.datasets.cifar10
(x_train,y_train),(x_test,y_test) = dt.load_data()
x_train,x_test = x_train/255.0,x_test/255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
import cv2

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[311])

# %%
model = keras.Sequential([
    layers.Flatten(input_shape = (32,32,3)),
    layers.Dense(256,activation = 'relu'),
    layers.Dense(128,activation = 'relu'),
    layers.Dense(10,activation = 'softmax')
])

# %%
model.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

# %%
history = model.fit(x_train,y_train,validation_split=.1,epochs = 25)
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 22s 14ms/step - loss: 1.8763 - accuracy: 0.3226 - val_loss: 1.7824 - val_accuracy: 0.3484
# Epoch 2/25
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.7013 - accuracy: 0.3891 - val_loss: 1.6595 - val_accuracy: 0.4040
# Epoch 3/25
# 1407/1407 [==============================] - 21s 15ms/step - loss: 1.6249 - accuracy: 0.4159 - val_loss: 1.6987 - val_accuracy: 0.3862
# Epoch 4/25
# 1407/1407 [==============================] - 21s 15ms/step - loss: 1.5738 - accuracy: 0.4354 - val_loss: 1.5970 - val_accuracy: 0.4206
# Epoch 5/25
# 1407/1407 [==============================] - 19s 14ms/step - loss: 1.5335 - accuracy: 0.4478 - val_loss: 1.5851 - val_accuracy: 0.4316
# Epoch 6/25
# 1407/1407 [==============================] - 23s 16ms/step - loss: 1.5020 - accuracy: 0.4616 - val_loss: 1.5593 - val_accuracy: 0.4324
# Epoch 7/25
# 1407/1407 [==============================] - 19s 13ms/step - loss: 1.4779 - accuracy: 0.4716 - val_loss: 1.5216 - val_accuracy: 0.4588
# Epoch 8/25
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.4514 - accuracy: 0.4803 - val_loss: 1.5065 - val_accuracy: 0.4616
# Epoch 9/25
# 1407/1407 [==============================] - 21s 15ms/step - loss: 1.4368 - accuracy: 0.4837 - val_loss: 1.5177 - val_accuracy: 0.4658
# Epoch 10/25
# 1407/1407 [==============================] - 19s 13ms/step - loss: 1.4160 - accuracy: 0.4931 - val_loss: 1.4884 - val_accuracy: 0.4778
# Epoch 11/25
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.3989 - accuracy: 0.4977 - val_loss: 1.4933 - val_accuracy: 0.4680
# Epoch 12/25
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3926 - accuracy: 0.5015 - val_loss: 1.4963 - val_accuracy: 0.4708
# Epoch 13/25
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3773 - accuracy: 0.5064 - val_loss: 1.4667 - val_accuracy: 0.4880
# Epoch 14/25
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3653 - accuracy: 0.5104 - val_loss: 1.4954 - val_accuracy: 0.4690
# Epoch 15/25
# 1407/1407 [==============================] - 19s 13ms/step - loss: 1.3516 - accuracy: 0.5149 - val_loss: 1.4574 - val_accuracy: 0.4886
# Epoch 16/25
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3418 - accuracy: 0.5185 - val_loss: 1.4960 - val_accuracy: 0.4762
# Epoch 17/25
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.3332 - accuracy: 0.5213 - val_loss: 1.4854 - val_accuracy: 0.4774
# Epoch 18/25
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3255 - accuracy: 0.5233 - val_loss: 1.4457 - val_accuracy: 0.5002
# Epoch 19/25
# 1407/1407 [==============================] - 19s 13ms/step - loss: 1.3153 - accuracy: 0.5297 - val_loss: 1.4595 - val_accuracy: 0.4884
# Epoch 20/25
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3086 - accuracy: 0.5340 - val_loss: 1.4953 - val_accuracy: 0.4770
# Epoch 21/25
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3006 - accuracy: 0.5333 - val_loss: 1.4659 - val_accuracy: 0.4856
# Epoch 22/25
# 1407/1407 [==============================] - 19s 13ms/step - loss: 1.2949 - accuracy: 0.5377 - val_loss: 1.4619 - val_accuracy: 0.4888
# Epoch 23/25
# 1407/1407 [==============================] - 19s 13ms/step - loss: 1.2916 - accuracy: 0.5357 - val_loss: 1.4921 - val_accuracy: 0.4830
# Epoch 24/25
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2762 - accuracy: 0.5439 - val_loss: 1.4443 - val_accuracy: 0.4950
# Epoch 25/25
# 1407/1407 [==============================] - 19s 13ms/step - loss: 1.2734 - accuracy: 0.5430 - val_loss: 1.4866 - val_accuracy: 0.4912

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train data','validation data'],loc = 'lower right')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train data','validation data'],loc = 'lower right')

# %%
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis = 1)
y_pred
# Out:
# 313/313 [==============================] - 1s 4ms/step
# array([8, 1, 8, ..., 2, 3, 7])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.4908

# %%
img = x_test[560]
plt.imshow(img)
plt.xlabel(f"Y_pred{y_pred[560]} ,Y_test{y_test[560]}")
# Out:
# Text(0.5, 0, 'Y_pred0 ,Y_test[0]')
